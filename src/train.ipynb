# %%
import os
from ultralytics import YOLO

current_dir = os.getcwd()
if current_dir.endswith('src'):
    os.chdir('..')

model = YOLO("model/yolov8n.pt")

model.train(
    data="construction_dataset/data.yaml",
    epochs=50,
    imgsz=640,
    project="model",
    name="construction_train"
)


model.save('model/best.pt')
# Out:
# Step 1: Loading the base YOLOv8 model for transfer learning...
# Step 2: Starting the training process on the construction dataset...
# New https://pypi.org/project/ultralytics/8.4.41 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.10.20 torch-2.11.0 CPU (Apple M3)
# ...
